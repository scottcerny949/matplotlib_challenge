# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import os

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_data_df = study_results.merge(mouse_metadata, on = "Mouse ID")

# Display the data table for preview
merged_data_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
merged_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Timepoint           1893 non-null   int64
#  2   Tumor Volume (mm3)  1893 non-null   float64
#  3   Metastatic Sites    1893 non-null   int64
#  4   Drug Regimen        1893 non-null   object
#  5   Sex                 1893 non-null   object
#  6   Age_months          1893 non-null   int64
#  7   Weight (g)          1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 133.1+ KB

# %%
merged_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
merged_data_df['Tumor Volume (mm3)'].describe()
# Out:
# count    1893.000000
# mean       50.448381
# std         8.894722
# min        22.050126
# 25%        45.000000
# 50%        48.951474
# 75%        56.292200
# max        78.567014
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Checking the number of mice.
num_mice = merged_data_df["Mouse ID"].count()
print(f"the number of mice is: {num_mice}")
# Out:
# the number of mice is: 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Optional: Get all the data for the duplicate mouse ID. 
dupes = merged_data_df[merged_data_df.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]
dupes
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# ...

# %%
#show just the g989 Mouse ID data
g989 = merged_data_df[merged_data_df['Mouse ID'] == 'g989']
g989
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#cleaned = merged_data_df.drop_duplicates(subset=['Mouse ID', 'Timepoint'])
cleaned_df = merged_data_df[merged_data_df['Mouse ID'] != 'g989']
cleaned_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
num_mice2 = cleaned_df["Mouse ID"].count()
print(f"the number of mice is: {num_mice2}")
# Out:
# the number of mice is: 1880

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

grouped_data = cleaned_df.set_index('Drug Regimen').groupby(['Drug Regimen'])

# %%
mean_vol = grouped_data['Tumor Volume (mm3)'].mean()
mean_vol
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
sem_vol = grouped_data['Tumor Volume (mm3)'].sem()
sem_vol
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.544332
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
med_vol = grouped_data['Tumor Volume (mm3)'].median()
med_vol
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
var_vol = grouped_data['Tumor Volume (mm3)'].var()
var_vol
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     43.852013
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
std_vol = grouped_data['Tumor Volume (mm3)'].std()
std_vol
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.622085
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
stats_summary = pd.DataFrame({
                             "Mean": mean_vol,
                             "Median": med_vol,
                             "Variance": var_vol, 
                             "Standard Dev": std_vol, 
                             "SEM": sem_vol
                             })
stats_summary
# Out:
#                    Mean     Median   Variance  Standard Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764      4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177      6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684      6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577      8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479      8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083      7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013      6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704      4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562      7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355      6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

stats_summary_agg = grouped_data['Tumor Volume (mm3)'].aggregate(['mean', 'median', 'var', 'std', 'sem'])
stats_summary_agg
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

count_vol = grouped_data['Tumor Volume (mm3)'].count()
count_vol
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     148
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Tumor Volume (mm3), dtype: int64

# %%
measurement_count = pd.DataFrame({
                             "Measurements": count_vol,
                             })
measurement_count
# Out:
#               Measurements
# Drug Regimen
# Capomulin              230
# Ceftamin               178
# Infubinol              178
# Ketapril               188
# Naftisol               186
# Placebo                181
# Propriva               148
# Ramicane               228
# Stelasyn               181
# Zoniferol              182

# %%
measurement_count.plot(kind="bar", facecolor="red", legend=False, width=.5)

plt.title("Measurments Taken per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")

plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

count_list = list(count_vol)
count_list
# Out:
# [230, 178, 178, 188, 186, 181, 148, 228, 181, 182]

# %%
regimen_list = list(stats_summary.index.values)
regimen_list
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
#drug_list = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol']
plt.bar(regimen_list, count_list, color="r", align="center", width=.5)
plt.title("Measurments Taken per Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
sex_data = cleaned_df.set_index('Sex').groupby(['Sex'])
sex_count = sex_data['Mouse ID'].count()
sex_count
# Out:
# Sex
# Female    922
# Male      958
# Name: Mouse ID, dtype: int64

# %%
gender_count = pd.DataFrame({
                             "Sex": sex_count
                              })
gender_count
# Out:
#         Sex
# Sex
# Female  922
# Male    958

# %%
colors = ["lightcoral", "lightskyblue"]
gender_count.plot(kind="pie", y="Sex", colors=colors, autopct="%1.1f%%", ylabel=" ", shadow=True, startangle=90, legend=False, title="Distribution by Sex")
plt.axis("equal")
plt.show()

# %%
sex_count_list = list(sex_count)
sex_count_list
# Out:
# [922, 958]

# %%
sex_list = list(sex_count.index.values)
sex_list
# Out:
# ['Female', 'Male']

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

colors = ["lightcoral", "lightskyblue"]
plt.title("Distribution by Sex")
plt.pie(sex_count_list, labels=sex_list, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin


# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Start by getting the last (greatest) timepoint for each mouse
greatest_tp_df = pd.DataFrame(cleaned_df.groupby('Mouse ID')['Timepoint'].max().reset_index())
greatest_tp_df
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
greatest_tp_df2 = pd.DataFrame(greatest_tp_df.rename(columns={'Timepoint': 'max_timepoint'}))
greatest_tp_df2
# Out:
#     Mouse ID  max_timepoint
# 0       a203             45
# 1       a251             45
# 2       a262             45
# 3       a275             45
# 4       a366             30
# ..       ...            ...
# 243     z435             10
# 244     z578             45
# 245     z581             45
# 246     z795             45
# 247     z969             45
#
# [248 rows x 2 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

merged_new_df = cleaned_df.merge(greatest_tp_df2, on = "Mouse ID")
merged_new_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)  max_timepoint
# 0  Female           9          22             45
# 1  Female           9          22             45
# 2  Female           9          22             45
# 3  Female           9          22             45
# 4  Female           9          22             45

# %%
# Put treatments into a list for for loop (and later for plot labels)
drug_reg = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
ol_count = 0

print(f"IQR, Bounds, and Outliers Data for Each Drug Regimen:")
print(f" ")

for reg in drug_reg:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    reg_df = merged_new_df.loc[merged_new_df['Drug Regimen'] == reg]
    final_df = reg_df.loc[reg_df['Timepoint'] == reg_df['max_timepoint']]
    
    # add subset
    final_num = final_df['Tumor Volume (mm3)']
    tumor_vol_list.append(final_num)
    
    print(f"{reg}:")
    
    # Determine outliers using upper and lower bounds
    
    #finding quartiles for each regimen
    quartiles = final_num.quantile([0.25,0.5,0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q
    print(f"IQR: {iqr}")
    
    # finding lower and upper bounds for each regimen
    lower_b = lower_q - (1.5 * iqr)
    upper_b = upper_q + (1.5 * iqr)
    print(f"Lower Bound: {lower_b}")
    print(f"Upper Bound: {upper_b}")
    
    # finding outliers for each regimen
    #need to figure out how to count the outliers based on above info
    lower_ol = (final_num.loc[(final_df['Tumor Volume (mm3)'] < lower_b)]).count()
    upper_ol = (final_num.loc[(final_df['Tumor Volume (mm3)'] > upper_b)]).count()                          
    ol_count = (upper_ol + lower_ol)
    print(f"Outliers: {ol_count}")
    print(f" ")
# Out:
# IQR, Bounds, and Outliers Data for Each Drug Regimen:
#
# Capomulin:
# IQR: 7.781863460000004
# Lower Bound: 20.70456164999999
# Upper Bound: 51.83201549
# Outliers: 0
#
# Ramicane:
# IQR: 9.098536719999998
# Lower Bound: 17.912664470000003
# Upper Bound: 54.30681135
# Outliers: 0
#
# Infubinol:
# IQR: 11.477135160000003
# Lower Bound: 36.83290494999999
# Upper Bound: 82.74144559000001
# Outliers: 1
#
# Ceftamin:
# IQR: 15.577752179999997
# Lower Bound: 25.355449580000002
# Upper Bound: 87.66645829999999
# Outliers: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
outliers = dict(markerfacecolor='blue', marker='s', markersize=10, markeredgecolor='black')
fig1, ax1 = plt.subplots()
ax1.boxplot(tumor_vol_list, flierprops=outliers)
ax1.set_title('Final Tumor Volume')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.xlabel('Drug Regimen')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# I'm using mouse m601 for this 

m601_df = cleaned_df.loc[cleaned_df['Mouse ID'] == 'm601']
m601_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1883     m601          0           45.000000                 0    Capomulin
# 1884     m601          5           41.408591                 1    Capomulin
# 1885     m601         10           36.825367                 1    Capomulin
# 1886     m601         15           35.464612                 1    Capomulin
# 1887     m601         20           34.255732                 1    Capomulin
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#        Sex  Age_months  Weight (g)
# 1883  Male          22          17
# 1884  Male          22          17
# ...

# %%
plt.plot(m601_df['Timepoint'], m601_df['Tumor Volume (mm3)'], marker='s', color='r')
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Mouse m601 Capomulin Results")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capo_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Capomulin']
capo_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
avg_tumor_df = pd.DataFrame(capo_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().reset_index())
avg_tumor_df
# Out:
#    Mouse ID  Tumor Volume (mm3)
# 0      b128           41.963636
# 1      b742           40.083699
# 2      f966           36.505973
# 3      g288           41.990097
# 4      g316           44.613344
# 5      i557           44.805810
# 6      i738           39.141053
# 7      j119           44.465236
# 8      j246           43.216925
# 9      l509           44.434474
# 10     l897           42.507261
# 11     m601           34.847470
# 12     m957           39.049816
# 13     r157           45.798970
# 14     r554           36.509212
# 15     r944           43.367364
# 16     s185           34.559143
# 17     s710           42.803733
# 18     t565           39.328725
# 19     u364           39.887495
# 20     v923           41.581595
# 21     w150           41.384825
# 22     w914           41.352452
# 23     x401           36.182040
# 24     y793           38.506829

# %%
avg_tumor_df2 = pd.DataFrame(avg_tumor_df.rename(columns={'Tumor Volume (mm3)': 'avg_volume'}))
avg_tumor_df2
# Out:
#    Mouse ID  avg_volume
# 0      b128   41.963636
# 1      b742   40.083699
# 2      f966   36.505973
# 3      g288   41.990097
# 4      g316   44.613344
# 5      i557   44.805810
# 6      i738   39.141053
# 7      j119   44.465236
# 8      j246   43.216925
# 9      l509   44.434474
# 10     l897   42.507261
# 11     m601   34.847470
# 12     m957   39.049816
# 13     r157   45.798970
# 14     r554   36.509212
# 15     r944   43.367364
# 16     s185   34.559143
# 17     s710   42.803733
# 18     t565   39.328725
# 19     u364   39.887495
# 20     v923   41.581595
# 21     w150   41.384825
# 22     w914   41.352452
# 23     x401   36.182040
# 24     y793   38.506829

# %%
merged_avg_tumor_df = capo_df.merge(avg_tumor_df2, on = "Mouse ID")
merged_avg_tumor_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)  avg_volume
# 0  Female           9          22   41.963636
# 1  Female           9          22   41.963636
# 2  Female           9          22   41.963636
# 3  Female           9          22   41.963636
# 4  Female           9          22   41.963636

# %%
plt.scatter(merged_avg_tumor_df['Weight (g)'], merged_avg_tumor_df['avg_volume'], color="green", marker='o')
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Average Tumor Volume by Weight - Capomulin")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
